# %%
import akshare as ak
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'SimHei'  # Linux 请注意字体设置问题
plt.rcParams['axes.unicode_minus'] = False

stock_df = ak.zdzk_fund_index(30, plot=False)  # 股票策略数据
futures_df = ak.zdzk_fund_index(32, plot=False)  # 管理期货策略数据

fig = plt.figure(111, figsize=(20, 10), dpi=300)
adjust_stock_df = stock_df["20150102":] / stock_df["20150102"] * 1000
adjust_stock_df.plot(linewidth=1)
adjust_futures_df = futures_df["20150102":] / futures_df["20150102"] * 1000
adjust_futures_df.plot(linewidth=1)
plt.title("智道智科股票策略和管理期货策略指数")
plt.legend()
plt.show()

# %%
import akshare as ak
# ak.__version__
stock_zh_a_spot_df = ak.stock_zh_a_spot()
# stock_zh_a_daily_hfq_df = ak.stock_zh_a_daily(symbol="sh600582", adjust="hfq")
print("")
print(stock_zh_a_spot_df[:2])
# Out:
# Please wait for a moment: 100%|██████████| 48/48 [00:21<00:00,  2.21it/s]
#      symbol    code  name   trade pricechange changepercent     buy    sell  \
# 0  sh600000  600000  浦发银行  10.380       0.040         0.387  10.370  10.380
# 1  sh600004  600004  白云机场  13.980      -0.100        -0.710  13.970  13.980
#
#   settlement    open    high     low    volume     amount  ticktime     per  \
# 0     10.340  10.310  10.390  10.280  15574310  160783648  15:00:00   5.323
# 1     14.080  14.000  14.020  13.820  17511237  243762307  15:00:03  29.125
#
#       pb        mktcap           nmc  turnoverratio
# 0  0.591  3.046746e+07  2.917171e+07        0.05542
# 1  1.746  2.892910e+06  2.892910e+06        0.84623

# %%
import akshare as ak
stock_zh_a_daily_hfq_df = ak.stock_zh_a_daily(symbol="sh600000", adjust="hfq")
print(stock_zh_a_daily_hfq_df)
# Out:
# open        high         low       close       volume  \
# date
# 1999-11-10   29.500000   29.800000   27.000000   27.750000  174085100.0
# 1999-11-11   27.580000   28.380000   27.530000   27.710000   29403500.0
# 1999-11-12   27.860000   28.300000   27.770000   28.050000   15008000.0
# 1999-11-15   28.200000   28.250000   27.700000   27.750000   11921100.0
# 1999-11-16   27.880000   27.970000   26.480000   26.550000   23223100.0
# ...                ...         ...         ...         ...          ...
# 2020-05-07  132.952475  133.079703  131.934657  132.189112   26211656.0
# 2020-05-08  132.825248  133.461384  132.316339  132.825248   20927670.0
# 2020-05-11  132.825248  134.097521  132.570794  132.698021   21472495.0
# 2020-05-12  132.825248  133.334157  131.552976  131.552976   19405945.0
# 2020-05-13  131.171294  132.189112  130.789612  132.061885   15574310.0
#
#             outstanding_share  turnover
# date
# 1999-11-10       3.200000e+08  0.544016
# 1999-11-11       3.200000e+08  0.091886
# 1999-11-12       3.200000e+08  0.046900
# 1999-11-15       3.200000e+08  0.037253
# 1999-11-16       3.200000e+08  0.072572
# ...                       ...       ...
# 2020-05-07       2.810342e+10  0.000933
# 2020-05-08       2.810342e+10  0.000745
# 2020-05-11       2.810342e+10  0.000764
# 2020-05-12       2.810342e+10  0.000691
# 2020-05-13       2.810342e+10  0.000554
#
# [4849 rows x 7 columns]
